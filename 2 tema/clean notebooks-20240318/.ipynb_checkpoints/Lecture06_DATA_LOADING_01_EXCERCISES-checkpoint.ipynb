# %% [markdown]
# # DATA LOADING

# %% [markdown]
# ### EX. 1

# %% [markdown]
# Import a random csv file into python.

# %%
import pandas as pd
pd.read_csv('data/examples/ex1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# ### EX. 2

# %% [markdown]
# Import a random csv file that changes its columns into index.

# %%
names = ['a', 'b', 'c', 'd', 'message']
pd.read_csv('data/examples/ex2.csv', names=names, index_col='message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %% [markdown]
# ### EX. 3

# %% [markdown]
# Import a large csv file and display 100 rows.

# %%
box = pd.read_csv('data/examples/ex6.csv')

# %%
pd.set_option('display.min_rows', 101)

# %%
box.head(100)
# Out:
#          one       two     three      four key
# 0   0.467976 -0.038649 -0.295344 -1.824726   L
# 1  -0.358893  1.404453  0.704965 -0.200638   B
# 2  -0.501840  0.659254 -0.421691 -0.057688   G
# 3   0.204886  1.074134  1.388361 -0.982404   R
# 4   0.354628 -0.133116  0.283763 -0.837063   Q
# 5   1.817480  0.742273  0.419395 -2.251035   Q
# 6  -0.776764  0.935518 -0.332872 -1.875641   U
# 7  -0.913135  1.530624 -0.572657  0.477252   K
# 8   0.358480 -0.497572 -0.367016  0.507702   S
# 9  -1.740877 -1.160417 -1.637830  2.172201   G
# 10  0.240564 -0.328249  1.252155  1.072796   8
# 11  0.764018  1.165476 -0.639544  1.495258   R
# 12  0.571035 -0.310537  0.582437 -0.298765   1
# 13  2.317658  0.430710 -1.334216  0.199679   P
# 14  1.547771 -1.119753 -2.277634  0.329586   J
# 15 -1.310608  0.401719 -1.000987  1.156708   E
# 16 -0.088496  0.634712  0.153324  0.415335   B
# 17 -0.018663 -0.247487 -1.446522  0.750938   A
# 18 -0.070127 -1.579097  0.120892  0.671432   F
# ...

# %% [markdown]
# ### EX. 4

# %% [markdown]
# Read a csv file in pieces. Chuksizes.

# %% [markdown]
# ### EX. 5

# %% [markdown]
# Export csv file with a different seperator.For example "|".

# %% [markdown]
# ### EX. 6

# %% [markdown]
# Import the jaosn file.
#
# obj = """
# {"name": "Wes",
#  "places_lived": ["United States", "Spain", "Germany"],
#  "pet": null,
#  "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
#               {"name": "Katie", "age": 38,
#                "pets": ["Sixes", "Stache", "Cisco"]}]
# }
#
# Retrieve the age of Katie.

# %% [markdown]
# ### EX.7

# %% [markdown]
# Convert a jason file into dataframe using the siblings values.
#
# Import the json file.
#
# obj = """
# {"name": "Wes",
#  "places_lived": ["United States", "Spain", "Germany"],
#  "pet": null,
#  "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
#               {"name": "Katie", "age": 38,
#                "pets": ["Sixes", "Stache", "Cisco"]}]
# }

# %% [markdown]
# ### EX. 8

# %% [markdown]
# Download apple prices from yahoo api.

# %% [markdown]
# ### EX. 9

# %% [markdown]
# Download data from worldbank for multiple countries and mutiple indicators.

# %% [markdown]
# ### EX. 10

# %% [markdown]
# Import a random excel file into a dataframe.
