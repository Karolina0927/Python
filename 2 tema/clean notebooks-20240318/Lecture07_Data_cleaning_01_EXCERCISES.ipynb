# %% [markdown]
# # Data Cleaning and Preparation

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %% [markdown]
# ### EX. 1

# %% [markdown]
# string_data = pd.Series(['aardvark', 'artichoke', np.nan, 'avocado'])
# Check for missing data in the latter Series.

# %% [markdown]
# ### EX.2

# %%
In the following series make second value None. string_data = pd.Series(['aardvark', 'artichoke', np.nan, 'avocado'])

# %% [markdown]
# ### EX. 3

# %%
Drop empty values for the following series data = pd.Series([1, NA, 3.5, NA, 7])

# %% [markdown]
# ### EX. 4

# %% [markdown]
# Drop only those values that have all Nan. data = pd.DataFrame([[1., 6.5, 3.], [1., NA, NA],
#                                                              [NA, NA, NA], [NA, 6.5, 3.]])

# %% [markdown]
# ### EX. 5

# %%
Remove rows that contain more that 3 Nan.
# Out:
#   File "<ipython-input-15-2b21bbe072a3>", line 1
#     Remove rows that contain more that 3 Nan.
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Ex. 6

# %% [markdown]
# FIll all empty values with 5

# %% [markdown]
# ### EX. 7

# %%
Fill in the '0' column 99, and in the '2' column 888

# %% [markdown]
# ### EX 8

# %%
Fill the NaN values with the last avaialbe data in the table.

# %% [markdown]
# ### EX 9

# %%
FIll the empty values of the series with a mean. pd.Series([1., NA, 3.5, NA, 7])

# %% [markdown]
# #### EX. 10

# %% [markdown]
# Create a dataframe with duplicated values and show there boolean values. When drop duplicate values.

# %% [markdown]
# ### EX. 11

# %% [markdown]
# df = pd.DataFrame({
#     'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
#     'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
#     'rating': [4, 4, 3.5, 15, 5] })
#
# a) drop duplicates in the style.
# b) drop duplicates in brand keeping the last.

# %% [markdown]
# ### EX. 12

# %% [markdown]
# data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon',
#                               'pastrami', 'corned beef', 'bacon',
#                               'pastrami', 'honey ham', 'nova lox'],
#                      'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
#
# Create a dictionary and map it's values to food.

# %% [markdown]
# ### EX. 13

# %% [markdown]
# Replace all the values of -999, 1. and 2.  to 'None' for the following series. pd.Series([1., -999., 2., -999., -1000., 3.])

# %% [markdown]
# ### EX. 15

# %%
Rename the Ohio column into "Kaunas"
data = pd.DataFrame(np.arange(12).reshape((3, 4)),
                    index=['Ohio', 'Colorado', 'New York'],
                    columns=['one', 'two', 'three', 'four'])

# %% [markdown]
# ### EX. 15

# %% [markdown]
# Create 5 bins of the following list ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

# %% [markdown]
# ### EX 16

# %%
Cut the follwoing into equal categories data = np.random.randn(1000)
