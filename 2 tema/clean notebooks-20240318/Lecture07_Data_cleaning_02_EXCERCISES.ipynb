# %% [markdown]
# # Data Cleaning and Preparation

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %% [markdown]
# ### EX. 1

# %% [markdown]
# Get dummy values of the following dataframe.
# df = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'b'],
#                    'data1': range(6)})

# %% [markdown]
# ### EX.2

# %% [markdown]
# Remove the whitespace from the stinrg  gor = 'Car loft'

# %% [markdown]
# ### EX. 3

# %%
Split the string into different strings according to comma and remove all white sapce val = 'I was born ,I was not born,  I want ice!!!cream'

# %% [markdown]
# ### EX. 4

# %% [markdown]
# Join the pieces of the folliwng strings: "As" ,  "Arba tu", "mes kartu"

# %% [markdown]
# ### EX. 5

# %% [markdown]
# Split the stirng using regex by whitespaces text = "GURURURUR    VIDMANTAS\t baz  EEEEEE".

# %% [markdown]
# ### Ex. 6

# %% [markdown]
# Find a string that contains ".com"
#
# data = {'Dave': 'dave@google.com', 'Steve': 'steve@gmail.com',
#         'Rob': 'rob@gmail.com', 'Wes': np.nan}
