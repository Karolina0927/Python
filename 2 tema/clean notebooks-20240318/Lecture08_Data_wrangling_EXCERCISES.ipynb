# %% [markdown]
# # Data WRANGLING

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %% [markdown]
# ### EX. 1

# %% [markdown]
# Create a multi index series with index a, b, c, d and index a and c rows.

# %%
data = pd.DataFrame(np.random.rand(3), index=[['a', 'b', 'c'], [1,2,3]])

# %%
data.loc[['a', 'b']]
# Out:
#             0
# a 1  0.574237
# b 2  0.615028

# %%
data['a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data['a']
#
# File /opt/anaconda3/envs/LEC_2/lib/python3.10/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File /opt/anaconda3/envs/LEC_2/lib/python3.10/site-packages/pandas/core/indexes/range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'a'

# %% [markdown]
# ### EX.2

# %%
From the inner level select all values that correspond to 3. 

data = pd.Series(np.random.randn(9),
                 index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                        [1, 2, 3, 1, 3, 1, 2, 2, 3]])

# %%
data = pd.Series(np.random.randn(9),
                 index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                        [1, 2, 3, 1, 3, 1, 2, 2, 3]])

# %%
data[:,3]
# Out:
# a   -1.157659
# b   -0.369956
# d   -0.079953
# dtype: float64

# %% [markdown]
# ### EX. 3

# %%
For the following dataframe. Create names for the index as key_1 and key_2. When swap their positions so that key 2 is first. After that reset the index.

frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                     index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                     columns=[['Ohio', 'Ohio', 'Colorado'],
                              ['Green', 'Red', 'Green']])

# %% [markdown]
# ### EX. 4

# %% [markdown]
# Merge the following to dataframes.
#
# df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
#                     'data1': range(7)})
# df2 = pd.DataFrame({'key': ['a', 'b', 'd'],
#                     'data2': range(3)})

# %% [markdown]
# ### Ex. 5

# %% [markdown]
# Merge the following two dataframes.
#
# df3 = pd.DataFrame({'lkey': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
#                     'data1': range(7)})
# df4 = pd.DataFrame({'rkey': ['a', 'b', 'd'],
#                     'data2': range(3)})

# %% [markdown]
# ### EX. 6

# %%
Merge the follwing dataframes so that values that do not exist in other dataframe will be incldued.

df3 = pd.DataFrame({'lkey': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                    'data1': range(7)})
df4 = pd.DataFrame({'rkey': ['a', 'b', 'd'],
                    'data2': range(3)})

# %% [markdown]
# ### Ex.7

# %%
Join the following dataframes on the df1 key1.

df1 = pd.DataFrame({'key1': ['b', 'b', 'a', 'c', 'a', 'b'],
                    'data1': range(6)})
df2 = pd.DataFrame({'key': ['a', 'b', 'a', 'b', 'd'],
                    'data2': range(5)})

# %% [markdown]
# ### EX.8

# %%
Join two dataframes by using the right index and left key1 and key2.

left = pd.DataFrame({'key1': ['Ohio', 'Ohio', 'Ohio',
                               'Nevada', 'Nevada'],
                      'key2': [2000, 2001, 2002, 2001, 2002],
                      'data': np.arange(5.)})
right = pd.DataFrame(np.arange(12).reshape((6, 2)),
                      index=[['Nevada', 'Nevada', 'Ohio', 'Ohio',
                              'Ohio', 'Ohio'],
                             [2001, 2000, 2000, 2000, 2001, 2002]],
                      columns=['event1', 'event2'])

# %% [markdown]
# ### EX. 9

# %%
Join two dataframes using both indexes.

left2 = pd.DataFrame([[1., 2.], [3., 4.], [5., 6.]],
                     index=['a', 'c', 'e'],
                     columns=['Ohio', 'Nevada'])
right2 = pd.DataFrame([[7., 8.], [9., 10.], [11., 12.], [13, 14]],
                      index=['b', 'c', 'd', 'e'],
                      columns=['Missouri', 'Alabama'])

# %% [markdown]
# ### EX. 10

# %%
Concetenate the arr with itself. 

arr = np.arange(12).reshape((3, 4))

# %% [markdown]
# ### EX. 12

# %%
Concatenate the following dataframes

s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])

# %% [markdown]
# ### EX.13

# %%
Use combine first for the following dataframes.

df1 = pd.DataFrame({'a': [1., np.nan, 5., np.nan],
                    'b': [np.nan, 2., np.nan, 6.],
                    'c': range(2, 18, 4)})
df2 = pd.DataFrame({'a': [5., 4., np.nan, 3., 7.],
                    'b': [np.nan, 3., 4., 6., 8.]})

# %% [markdown]
# ### EX. 14

# %%
Melt the following dataframe into on top of each other.

df = pd.DataFrame({'key': ['foo', 'bar', 'baz'],
                   'A': [1, 2, 3],
                   'B': [4, 5, 6],
                   'C': [7, 8, 9]})
