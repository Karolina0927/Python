# %% [markdown]
# # MATPLOTLIB

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA
import matplotlib.pyplot as plt
plt.style.use('default')

# %% [markdown]
# ### EX. 1

# %% [markdown]
# Plot a straight line with matplotlib.

# %% [markdown]
# ### EX.2

# %% [markdown]
# Create a figure with three subplots.

# %% [markdown]
# ### EX. 3

# %% [markdown]
# Create a random figure with dashed line.

# %% [markdown]
# ### EX. 4

# %% [markdown]
# Create a figure with six subplots and fill them with random graphs.

# %% [markdown]
# ### EX. 5

# %% [markdown]
# Create a function that draws a 4 subplot figure with histograms. Share x and y axis

# %% [markdown]
# ### Ex. 6

# %% [markdown]
# Create a figure with random data and draw using different markers.

# %% [markdown]
# ### EX. 7

# %% [markdown]
# Create a graph and set x value ticks to letters or strings. Add legends to the graphs.

# %% [markdown]
# ### EX. 8

# %% [markdown]
# Create a a line graph and make four annotations inside it.

# %% [markdown]
# ### EX.9

# %% [markdown]
# Create a line graph and save plot on your computer.

# %% [markdown]
# ### EX. 10

# %% [markdown]
# Create a barplot of a random data.

# %% [markdown]
# ### EX. 11

# %% [markdown]
# Create a barplot with different colors and draw legend inside the graph.

# %% [markdown]
# ### EX. 12

# %% [markdown]
# Import a file from the tips file called "tips.csv" and create a histogram of 'total_bill'

# %% [markdown]
# ### EX.13

# %% [markdown]
# Draw a seaborn pairplot with the following data. pd.read_csv('examples/macrodata.csv')
