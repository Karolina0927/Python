# %% [markdown]
# # Data AGGREGATION

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %% [markdown]
# ### EX. 1

# %% [markdown]
# df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
#                    'key2' : ['one', 'two', 'one', 'two', 'one'],
#                    'data1' : np.random.randn(5),
#                    'data2' : np.random.randn(5)})
#
# Group data according to data2 and key2 using the mean.

# %% [markdown]
# ### EX.2

# %% [markdown]
# Group data according to data2 and key 1 and key2 using the mean.

# %% [markdown]
# ### EX. 3

# %% [markdown]
# states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])
# years = np.array([2005, 2005, 2006, 2005, 2006])
#
# df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
#                    'key2' : ['one', 'two', 'one', 'two', 'one'],
#                    'data1' : np.random.randn(5),
#                    'data2' : np.random.randn(5)})
#
# Group according to states and years with data2 and sum the values.

# %% [markdown]
# ### EX. 4

# %% [markdown]
# people = pd.DataFrame(np.random.randn(5, 5),
#                       columns=['a', 'b', 'c', 'd', 'e'],
#                       index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])
#
# mapping = {'a': 'red', 'b': 'red', 'c': 'blue',
#            'd': 'blue', 'e': 'red', 'f' : 'orange'}
#
# Group and get the mean according to the mapping.

# %% [markdown]
# ### EX. 5

# %%
people = pd.DataFrame(np.random.randn(5, 5),
                      columns=['a', 'b', 'c', 'd', 'e'],
                      index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])
Group the names according to their name length and sum the values.

# %% [markdown]
# ### Ex. 6

# %% [markdown]
# df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
#                    'key2' : ['one', 'two', 'one', 'two', 'one'],
#                    'data1' : np.random.randn(5),
#                    'data2' : np.random.randn(5)})
# Group the data according to qunatile.

# %% [markdown]
# ### EX. 7

# %% [markdown]
# Using this dataset 'examples/tips.csv'.
# a) Calculate tip percentage and insert it in the dataframe. Group by day and smoker and calculate the mean.
# b) Futher, group according mean, std and max.
# c) Group two different columns using different grouping methods like mean and etc.

# %% [markdown]
# ### Ex.8

# %% [markdown]
# a) Write a function that selects the top values of the following dataset. Using this dataset 'examples/tips.csv'.
# b) Groupby smokers and find the top value.
# c) Apply a function to get only top vlaue.

# %% [markdown]
# ### EX.9

# %%
states = ['Ohio', 'New York', 'Vermont', 'Florida',
          'Oregon', 'Nevada', 'California', 'Idaho']
group_key = ['East'] * 4 + ['West'] * 4
data = pd.Series(np.random.randn(8), index=states)
data[['Vermont', 'Nevada', 'Idaho']] = np.nan

Find the mean according to the groupkeys.

# %% [markdown]
# ### EX. 10

# %%
Group the follwing dataset according to years.

close_px = pd.read_csv('examples/stock_px_2.csv', parse_dates=True,
                       index_col=0)

# %% [markdown]
# ### EX. 11

# %% [markdown]
# Create a pivot table for the tips dataset with smoker and day as indexes.

# %% [markdown]
# ### EX. 12

# %%
Import a file from the tips file called "tips.csv" and create a histogram of 'total_bill'

# %% [markdown]
# ### EX.13

# %%
Draw a seaborn pairplot with the following data. pd.read_csv('examples/macrodata.csv')
