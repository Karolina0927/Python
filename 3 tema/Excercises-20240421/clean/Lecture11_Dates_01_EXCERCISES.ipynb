# %% [markdown]
# # DATES

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %% [markdown]
# ### EX. 1

# %% [markdown]
# Find todays date.

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2024, 4, 21, 9, 27, 55, 621276)

# %% [markdown]
# ### EX.2

# %%
Find the difference between the following data. (2011, 1, 7) (2008, 6, 24) in second and months.

# %%
delta = datetime(2011, 1, 7) - datetime(2008, 6, 24)
delta.days
# Out:
# 927

# %% [markdown]
# ### EX. 3

# %% [markdown]
# Add six months to the following data datetime(2011, 1, 7).

# %%
from datetime import timedelta
datetime(2011, 1, 7) + timedelta(180)
# Out:
# datetime.datetime(2011, 7, 6, 0, 0)

# %% [markdown]
# ### EX. 4

# %% [markdown]
# Create a timestamp that shows year at the end rather than first from the following data. stamp= datetime(2011, 1, 3)

# %%
import numpy as np
import pandas as pd
datetime(2011,1,3).strftime("%d-%m-%y")
# Out:
# '03-01-11'

# %% [markdown]
# ### EX. 5

# %% [markdown]
# Use a parser to parse the following data ('2011-01-03').

# %% [markdown]
# ### Ex. 6

# %% [markdown]
# Create a pd.series with random dates. Try to index certain values.

# %% [markdown]
# ### EX. 7

# %% [markdown]
# Create a pd.series with date as index from 2002 to 2005. Try to index only 2004. Try to index only one month.

# %%
pd.Series(np.random.randn(10), index=pd.date_range(start= 2001, periods=10, freq='M'))
# Out:
# 1970-01-31 00:00:00.000002001   -0.148683
# 1970-02-28 00:00:00.000002001   -0.498755
# 1970-03-31 00:00:00.000002001    0.900700
# 1970-04-30 00:00:00.000002001   -2.008811
# 1970-05-31 00:00:00.000002001   -0.393253
# 1970-06-30 00:00:00.000002001    2.330501
# 1970-07-31 00:00:00.000002001    0.647077
# 1970-08-31 00:00:00.000002001    0.835537
# 1970-09-30 00:00:00.000002001   -0.501855
# 1970-10-31 00:00:00.000002001    0.458850
# Freq: M, dtype: float64

# %% [markdown]
# ### Ex.8

# %% [markdown]
# Slice the following values from day 8 to day 12
# dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
#          datetime(2011, 1, 7), datetime(2011, 1, 8),
#          datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %% [markdown]
# #### EX. 9

# %%
Aggregate the duplicate values of the following series and count them.
dates = pd.DatetimeIndex(['1/1/2000', '1/2/2000', '1/2/2000',
                          '1/2/2000', '1/3/2000'])
pd.Series(np.random.randn(5), index=dates)

# %% [markdown]
# ### EX.10

# %% [markdown]
# Resample the following dataframe into 2 hours and sum the values.
#
# index = pd.date_range('1/1/2000', periods=9, freq='T')
# series = pd.Series(range(9), index=index)

# %% [markdown]
# ### EX. 11

# %% [markdown]
# Generate a daterange from '2012-04-01', '2012-06-01'

# %% [markdown]
# ### EX. 12

# %% [markdown]
# Generate a series use business end of month

# %% [markdown]
# ### EX. 13

# %% [markdown]
# Find the second week of month of friday for the following date range. '2012-01-01', '2012-09-01'
