# %% [markdown]
# # DATES

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %% [markdown]
# ### EX. 1

# %% [markdown]
# Create a timestamp with timezone of Euorpe/ Moscow

# %% [markdown]
# ### EX.2

# %% [markdown]
# Add one hour to the following timestamps pd.Timestamp('2012-05-10 01:30', tz='US/Eastern')

# %% [markdown]
# ### EX. 3

# %% [markdown]
# Create an annual period with December as last month for year 2007 and add 2 years.

# %%
import pandas as pd
pd.Period('2007') + 2
# Out:
# Period('2009', 'A-DEC')

# %% [markdown]
# ### EX. 4

# %% [markdown]
# Create an annual period with December as last month for year 2010 and convert it to monthly period using start.

# %%
pd.Period('2010').asfreq('M')
# Out:
# Period('2010-12', 'M')

# %% [markdown]
# ### EX. 5

# %% [markdown]
# Find the first day and month of frequency 'Q-DEC' for '2010Q3' using Python.

# %%
pd.Period('2010', freq='Q-DEC').asfreq('D', how='start')
# Out:
# Period('2010-01-01', 'D')

# %% [markdown]
# ### Ex. 6

# %% [markdown]
# Get the timestamp at 5 PM on the third-to-last business day of the quarter of frequency 'Q-JAN' for '2010Q3'.

# %% [markdown]
# ### EX. 7

# %% [markdown]
# Create a daily data_range from 2000 to 2001 and convert it to monthly frequency using the mean.

# %% [markdown]
# ### Ex.8

# %% [markdown]
# Resample the following. dataframe into daily.
