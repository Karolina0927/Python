# %% [markdown]
# # INTEGRALS

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA
import sympy as Sympy

# %% [markdown]
# ### EX. 1

# %% [markdown]
# Using sympy create a symbol of. x, y and z.

# %% [markdown]
# ### EX.2

# %% [markdown]
# Write 2x + 1 in terms of symbols.

# %% [markdown]
# ### EX. 3

# %% [markdown]
# Factor the folowing equaiton expr = x**2 - y**2

# %% [markdown]
# ### EX. 4

# %% [markdown]
# Expand the following equation (𝑥−𝑦)(𝑥+𝑦)

# %% [markdown]
# ### EX. 5

# %%
Substitute values in the following expression. x = 5, y == 10
x = Symbol('x')
y = Symbol('y')
x*x + x*y + x*y + y*y

# %% [markdown]
# ### Ex. 6

# %%
Simplify following the expression 𝑦2+2𝑦(1−𝑦)+(1−𝑦)2

# %% [markdown]
# ### EX. 7

# %%
Solve the following expression expr = x - 5 - 10

# %% [markdown]
# ### Ex.8

# %%
Solve the quadratic equation. x2 + x + 1 = 0

# %% [markdown]
# #### EX. 9

# %%
expr1 = 2*x + 3*y - 6
expr2 = 3*x + 3*y -12

Solve the preceding linear equations. Verify the solution.

# %% [markdown]
# ### EX.10

# %% [markdown]
# Plot the following equaiton using sympy 2*x+3

# %% [markdown]
# ### EX. 11

# %%
Calculate derivative of the following functionn. (x**3 + x**2 + x)*(x**2+x).

Find the minima maxima.

# %% [markdown]
# ### EX. 12

# %% [markdown]
# Find an integral of the following function. k*x
